# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn import svm, datasets
from sklearn.svm import LinearSVC
import numpy as np
iris = datasets.load_iris()

# %%
print(iris.target_names)
print(iris.feature_names)
# organized file will use sepal length and width
# Out:
# ['setosa' 'versicolor' 'virginica']
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
X =  iris.data[:, :2]
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]

print(a.size)
a = setosa [:25,:2]
print(a.size)
print(setosa.size)
# Out:
# 50
# 50
# 100

# %%
def svmFunc(X,y):
    clf = svm.SVC(kernel="linear", C=1000)
    
    #get_params([deep])
    #print (svm.class_weight)
    clf.fit(X, y)
    plt.scatter(X[:, 0],X[:, 1] ,c=y, s=30, cmap=plt.cm.Paired)

# plot the decision function
    ax = plt.gca()

    DecisionBoundaryDisplay.from_estimator(
        clf,
        X,
        plot_method="contour",
        colors="k",
        levels=[-1, 0, 1],
        alpha=0.5,
        linestyles=["--", "-", "--"],
        ax=ax,
    )

# plot support vectors

    ax.scatter(
        clf.support_vectors_[:, 0],
        clf.support_vectors_[:, 1],
        s=100,
        linewidth=1,
        facecolors="none",
        edgecolors="k",
    )

    plt.show()
    print("weights: ", clf.coef_)
    print("bias: ",clf.intercept_)

# %%
# fit the model, don't regularize for illustration purposes
#  speal width and length
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
#%timeit 
svmFunc(X,y)
#svmFunc(X,y)
#%memeit svmFunc(X,y)
# Out:
# weights:  [[ 6.31777572 -5.26481134]]
# bias:  [-17.32124155]

# %%
X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)
# Out:
# weights:  [[0.61538458 0.30769229]]
# bias:  [-2.2923075]

# %%
X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)
# Out:
# weights:  [[3.9982829  7.99442019]]
# bias:  [-32.58345299]

# %%
# sepal width and petal length
X =  iris.data[:, 1:3]
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]

# %%
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmFunc(X,y)
# Out:
# weights:  [[ 6.31777572 -5.26481134]]
# bias:  [-17.32124155]
# Wall time: 97.6 ms

# %%
X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

# %%
X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

# %%
# petal length and petal width
X =  iris.data[:, 2:4]
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]

X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)
# Out:
# weights:  [[1.29411744 0.82352928]]
# bias:  [-3.78823471]
# Wall time: 107 ms
# weights:  [[0.61538458 0.30769229]]
# bias:  [-2.2923075]
# weights:  [[3.9982829  7.99442019]]
# bias:  [-32.58345299]

# %%
# sepal length and petal length
X =   np.hstack ((iris.data[:, :1], iris.data[:, 2:3] ))
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]
#print(X)
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

# %%
# sepal length and petal width
X =   np.hstack ((iris.data[:, :1], iris.data[:, 3:4] ))
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]
#print(X)
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

# %%
# sepal width and petal width
X =   np.hstack ((iris.data[:, 1:2], iris.data[:, 3:4] ))
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]
#print(X)
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmFunc(X,y)

# %%
def svmLFunc(X,y):
    clf = svm.LinearSVC( C=1000)
    
    #get_params([deep])
    #print (svm.class_weight)
    clf.fit(X, y)
    
    plt.scatter(X[:, 0],X[:, 1] ,c=y, s=30, cmap=plt.cm.Paired)

# plot the decision function
    ax = plt.gca()

    DecisionBoundaryDisplay.from_estimator(
        clf,
        X,
        plot_method="contour",
        colors="k",
        levels=[-1, 0, 1],
        alpha=0.5,
        linestyles=["--", "-", "--"],
        ax=ax,
    )

# plot support vectors



    plt.show()
    clf

# %%
# sepal width and petal width
X =   np.hstack ((iris.data[:, 1:2], iris.data[:, 3:4] ))
y =  iris.target

setosa = X [:50,:2]
versicolor = X [50:100, :2]
virginica = X [100:150, :2]
#print(X)
X = np.concatenate((setosa, versicolor), axis=0)
y = y[:100]
svmLFunc(X,y)

X = np.concatenate((setosa, virginica), axis=0)
y = y[:100]
svmLFunc(X,y)

X = np.concatenate((versicolor, virginica), axis=0)
y = y[:100]
svmLFunc(X,y)
# Out:
# C:\Users\Dong Jun Woun\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\Dong Jun Woun\anaconda3\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
